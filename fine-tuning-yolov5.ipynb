# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.87-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.5.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.14.0)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.4.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.19.0)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.12.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.6-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2024.7.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.13.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.2.87-py3-none-any.whl (872 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 872.1/872.1 kB 20.8 MB/s eta 0:00:0000:01
# Downloading ultralytics_thop-2.0.6-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.2.87 ultralytics-thop-2.0.6
# Collecting roboflow
#   Downloading roboflow-1.1.44-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from roboflow) (2024.7.4)
# Requirement already satisfied: idna==3.7 in /opt/conda/lib/python3.10/site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /opt/conda/lib/python3.10/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from roboflow) (3.7.5)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /opt/conda/lib/python3.10/site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from roboflow) (9.5.0)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.10/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.26.18)
# Requirement already satisfied: tqdm>=4.41.0 in /opt/conda/lib/python3.10/site-packages (from roboflow) (4.66.4)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /opt/conda/lib/python3.10/site-packages (from roboflow) (0.10.1)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (4.53.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->roboflow) (3.3.2)
# Downloading roboflow-1.1.44-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 2.8 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Installing collected packages: filetype, roboflow
# Successfully installed filetype-1.2.0 roboflow-1.1.44

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="uIr63SZdyDmoBhnLhkTz")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(12)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-12 to yolov5pytorch:: 100%|██████████| 65763/65763 [00:02<00:00, 32683.95it/s]
# Extracting Dataset Version Zip to football-players-detection-12 in yolov5pytorch:: 100%|██████████| 756/756 [00:00<00:00, 3338.76it/s]

# %%
dataset.location
# Out:
# '/kaggle/working/football-players-detection-12'

# %%
import shutil

shutil.move('football-players-detection-12/train',
            'football-players-detection-12/football-players-detection-12/train')
shutil.move('football-players-detection-12/valid',
            'football-players-detection-12/football-players-detection-12/valid')
shutil.move('football-players-detection-12/test',
            'football-players-detection-12/football-players-detection-12/test')
# Out:
# 'football-players-detection-12/football-players-detection-12/test'

# %%
import os

# Disable W&B integration
os.environ['WANDB_MODE'] = 'disabled'

# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov5xu.pt to 'yolov5xu.pt'...
# 100%|█████████████████████████████████████████| 186M/186M [00:01<00:00, 119MB/s]
# Ultralytics YOLOv8.2.87 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: task=detect, mode=train, model=yolov5x.pt, data=/kaggle/working/football-players-detection-12/data.yaml, epochs=100, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 17.3MB/s]
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      8800  ultralytics.nn.modules.conv.Conv             [3, 80, 6, 2, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  4    309120  ultralytics.nn.modules.block.C3              [160, 160, 4]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  8   2259200  ultralytics.nn.modules.block.C3              [320, 320, 8]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1 12  13125120  ultralytics.nn.modules.block.C3              [640, 640, 12]
#   7                  -1  1   7375360  ultralytics.nn.modules.conv.Conv             [640, 1280, 3, 2]
#   8                  -1  4  19676160  ultralytics.nn.modules.block.C3              [1280, 1280, 4]
#   9                  -1  1   4099840  ultralytics.nn.modules.block.SPPF            [1280, 1280, 5]
#  10                  -1  1    820480  ultralytics.nn.modules.conv.Conv             [1280, 640, 1, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  4   5332480  ultralytics.nn.modules.block.C3              [1280, 640, 4, False]
#  14                  -1  1    205440  ultralytics.nn.modules.conv.Conv             [640, 320, 1, 1]
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  16             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  4   1335040  ultralytics.nn.modules.block.C3              [640, 320, 4, False]
#  18                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  19            [-1, 14]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  4   4922880  ultralytics.nn.modules.block.C3              [640, 640, 4, False]
#  21                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  22            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  4  19676160  ultralytics.nn.modules.block.C3              [1280, 1280, 4, False]
#  24        [17, 20, 23]  1  11025820  ultralytics.nn.modules.head.Detect           [4, [320, 640, 1280]]
# YOLOv5x summary: 493 layers, 97,203,260 parameters, 97,203,244 gradients, 246.9 GFLOPs
#
# Transferred 817/823 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.24.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|███████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 119MB/s]
# AMP: checks passed ✅
# train: Scanning /kaggle/working/football-players-detection-12/football-players-d
# train: New cache created: /kaggle/working/football-players-detection-12/football-players-detection-12/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /kaggle/working/football-players-detection-12/football-players-det
# val: New cache created: /kaggle/working/football-players-detection-12/football-players-detection-12/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 135 weight(decay=0.0), 142 weight(decay=0.0005), 141 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      14.7G      1.339      2.509     0.8834        328        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174       0.16      0.231       0.18      0.114
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      15.4G      1.177     0.9368     0.8411        309        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.133      0.374      0.152     0.0894
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      15.3G      1.164     0.7965     0.8389        223        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.403      0.533      0.305      0.169
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      15.4G      1.202     0.7597     0.8414        282        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.368       0.51      0.268      0.135
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      15.3G      1.233     0.8189     0.8505        359        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174       0.36      0.163      0.135     0.0588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      15.4G      1.275     0.8878     0.8528        296        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.563      0.553      0.521      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      15.7G      1.287     0.7919     0.8618        438        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.634      0.561      0.604       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      15.2G      1.276     0.7489     0.8449        221        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.722      0.553      0.621      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      15.4G      1.267     0.7437     0.8489        201        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.701      0.624      0.662      0.372
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      15.7G      1.244     0.6939     0.8363        208        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174       0.76      0.626        0.7      0.408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      15.7G      1.186     0.6614     0.8333        305        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174        0.8      0.668      0.696      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      15.2G      1.056     0.6089      0.827        408        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.824      0.614      0.725      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      15.4G      1.064     0.6097     0.8286        341        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.758      0.681      0.716      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      15.7G       1.08     0.6475     0.8303        304        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.597      0.708      0.594      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      15.7G      1.111     0.6476      0.826        312        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.848      0.691      0.759      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      15.8G      1.104     0.6156     0.8179        267        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.836      0.694      0.746       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      15.4G       1.01     0.5641     0.8216        346        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.811       0.75      0.779      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      15.7G      1.025     0.5582     0.8222        319        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.809      0.734      0.762       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      15.7G      1.012     0.5575     0.8206        391        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.862      0.646      0.743      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      15.7G      1.015     0.5457     0.8197        234        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.853      0.704      0.757      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      15.4G       1.05     0.5605     0.8184        344        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.892      0.708      0.762      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      15.7G      1.136     0.5898     0.8176        389        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.822      0.709       0.77      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      15.7G      1.103     0.5998     0.8185        246        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.594      0.613      0.597      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      15.8G      1.025     0.6018     0.8132        235        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.816      0.718       0.77      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      15.4G     0.9773     0.5339     0.8172        432        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.805      0.695      0.737      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      15.7G     0.9435     0.5312     0.8113        216        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.792      0.701      0.754      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      15.7G     0.9405     0.5207      0.813        283        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.774       0.73      0.741      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      15.2G     0.9684     0.5241     0.8129        272        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.809      0.698      0.738      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      15.4G      1.063     0.5455     0.8204        269        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.799      0.698      0.751      0.491
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      15.7G     0.9732     0.5192     0.8148        347        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.878      0.715      0.757      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      15.3G      1.025     0.5391      0.812        365        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.861      0.725      0.779      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      15.3G      1.048     0.5301     0.8197        376        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.872      0.716      0.775      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      15.4G     0.9786     0.5169     0.8133        244        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174       0.88       0.68      0.751      0.498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      15.7G     0.9487     0.4982     0.8071        289        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.839      0.751      0.779      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      15.8G     0.9261     0.4829     0.8059        311        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.802      0.745      0.766      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      15.2G     0.8976     0.4753     0.8106        226        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.871      0.759      0.798      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      15.4G     0.9005     0.4712      0.804        418        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.882       0.72      0.794      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      15.7G     0.9001      0.462     0.8046        214        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.874      0.714      0.781      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      15.6G     0.8813     0.4651     0.8011        418        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.925      0.764      0.805       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      15.7G     0.8989      0.463     0.8022        194        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.849      0.711      0.774      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      15.4G     0.9005     0.4734     0.8009        352        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.844      0.764      0.785      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      15.7G     0.8751     0.4688     0.8055        309        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174       0.88      0.721       0.77       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      15.8G     0.8989     0.4816     0.8083        297        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.853       0.74      0.799      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      15.7G     0.9237     0.4829     0.8053        322        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.851      0.733      0.788      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      15.4G     0.9163     0.4856     0.8107        356        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.874      0.711      0.783      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      15.7G     0.9033     0.4852     0.8127        256        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.879      0.768      0.808      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      15.7G     0.9232     0.4905     0.8089        341        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.838       0.77      0.815      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      15.8G     0.9071     0.4844     0.8055        317        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.796      0.768      0.777      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      15.4G     0.8702     0.4562     0.8022        404        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.836      0.767      0.794      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      15.4G     0.8513      0.449     0.7981        249        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.828      0.784      0.799      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      15.7G     0.8318     0.4397     0.8023        416        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.764      0.748      0.788      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      15.3G     0.8624     0.4389     0.8005        271        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.847      0.765      0.804      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      15.4G     0.9033     0.4591      0.803        263        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.908      0.765      0.818      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      15.7G      0.846     0.4313     0.8024        331        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.795      0.758      0.801      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      15.9G     0.8704     0.4391     0.7996        466        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.889      0.713      0.794      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      15.2G     0.8965     0.4531     0.8045        234        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.935       0.73       0.81      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      15.4G     0.8545     0.4347     0.8002        310        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.905      0.733      0.827      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      15.7G     0.8418      0.433     0.8079        320        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.865      0.756      0.816      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      15.7G     0.8351     0.4343     0.8003        260        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.874      0.755      0.801      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      15.2G     0.9225     0.4522     0.8019        381        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.937      0.732      0.819      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      15.4G     0.9376     0.4665     0.8116        255        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.849      0.726       0.78      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      15.7G     0.9388     0.4602     0.8021        349        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.824      0.746      0.789      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      15.7G     0.8526     0.4334     0.8005        354        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.877      0.703      0.754        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      15.8G     0.8298     0.4221     0.8002        342        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.846      0.762       0.79      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      15.4G     0.8272     0.4204     0.7955        385        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174       0.88       0.77      0.812      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      15.7G     0.8245     0.4203     0.7985        466        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.891      0.766      0.824       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      15.6G     0.8057     0.4052     0.7972        282        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.878      0.788      0.821      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      15.2G      0.829     0.4171     0.7992        369        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.871      0.762      0.799      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      15.4G     0.7992     0.4079     0.7954        271        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.916       0.74      0.806      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      15.7G      0.801     0.4035     0.7981        284        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.893      0.787      0.823      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      15.7G     0.7894     0.4031      0.797        297        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.902      0.764      0.823      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      15.8G     0.7848     0.4001     0.7969        213        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.907      0.782      0.831      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      15.4G     0.7997     0.4098     0.7968        202        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.901      0.771      0.816       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      15.7G     0.8327      0.418      0.798        237        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.903      0.762       0.81      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      15.7G     0.8044     0.4012     0.7964        355        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.888      0.767      0.801      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      15.3G     0.7985     0.3958     0.7945        288        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.872      0.766      0.801      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      15.4G      0.766     0.3869     0.7903        393        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.878       0.75      0.806      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      15.7G     0.8089     0.4015     0.7906        396        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.899      0.784       0.83      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      15.7G     0.7996     0.3921      0.797        295        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.886      0.781       0.82      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      15.2G     0.7953     0.3896     0.7977        364        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.926      0.756      0.811      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      15.4G      0.786     0.3877     0.7951        338        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.915      0.767      0.822      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      15.7G     0.7664      0.377     0.7958        177        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.894      0.773      0.812       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      15.7G      0.793      0.387     0.7914        304        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.899      0.767      0.811      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      15.3G     0.7453     0.3673     0.7897        247        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.934      0.772      0.827      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      15.1G     0.7419     0.3682     0.7909        359        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.906      0.777      0.829      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      15.7G     0.7517     0.3659     0.7892        271        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.943      0.751      0.823      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      15.7G     0.7525     0.3663     0.7927        345        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.927      0.758      0.826      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      15.3G     0.7324     0.3619     0.7918        328        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174       0.94      0.779      0.829      0.583
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      15.4G     0.7611     0.3721     0.7916        229        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.938      0.775      0.818      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      15.7G     0.7549     0.3685      0.795        264        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.946      0.765      0.819      0.582
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      15.6G     0.6815     0.3439     0.7861        232        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.954      0.777      0.823      0.589
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      15.8G     0.6781     0.3459     0.7896        220        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.956       0.78      0.827      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      15.4G     0.6753     0.3402     0.7903        230        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.959      0.778      0.828      0.589
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      15.7G     0.6739     0.3406     0.7931        235        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.946      0.773      0.827      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      15.7G     0.6737     0.3363     0.7867        227        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.934      0.781      0.827       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      15.8G     0.6689     0.3386     0.7868        239        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.952      0.771      0.829       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      15.4G       0.67     0.3359     0.7887        230        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.952      0.773       0.83      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      15.7G     0.6493     0.3258     0.7873        236        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174       0.94      0.778       0.83      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      15.7G      0.666     0.3304     0.7895        242        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.959      0.779       0.83      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      15.3G     0.6476     0.3221     0.7863        237        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.966      0.779      0.831      0.596
#
# 100 epochs completed in 0.854 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 195.0MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 195.0MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.87 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv5x summary (fused): 358 layers, 97,156,460 parameters, 0 gradients, 246.0 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         49       1174      0.966      0.779       0.83      0.596
#                   ball         45         45      0.995      0.333      0.452      0.203
#             goalkeeper         38         39      0.932      0.949      0.928      0.709
#                 player         49        973      0.982      0.952      0.986      0.811
#                referee         49        117      0.954       0.88      0.955      0.659
# Speed: 0.2ms preprocess, 30.0ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train
